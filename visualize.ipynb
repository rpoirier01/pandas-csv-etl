# %% [markdown]
# # Note:
# This is using the Ozone_Data_Trimmed.csv file which **DOES NOT** filter to a specific timeframe
# You could filter inside of this, but I like being able to see changes over time in the pivot table and line graph

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("venv/Ozone_Data_Trimmed.csv")

# %%
df.sort_values("Data Value", ascending=False)
# Out:
#             Name Measure                        Geo Place Name  Time Period  \
# 1118  Ozone (O3)    Mean     Rockaway and Broad Channel (CD14)  Summer 2023
# 313   Ozone (O3)    Mean                             Rockaways  Summer 2023
# 291   Ozone (O3)    Mean                             Rockaways  Summer 2023
# 345   Ozone (O3)    Mean                   Coney Island (CD13)  Summer 2023
# 769   Ozone (O3)    Mean         Coney Island - Sheepshead Bay  Summer 2023
# ...          ...     ...                                   ...          ...
# 913   Ozone (O3)    Mean              Upper East Side-Gramercy  Summer 2009
# 1609  Ozone (O3)    Mean                     Chelsea - Clinton  Summer 2009
# 873   Ozone (O3)    Mean  Stuyvesant Town and Turtle Bay (CD6)  Summer 2009
# 1550  Ozone (O3)    Mean           Gramercy Park - Murray Hill  Summer 2009
# 1930  Ozone (O3)    Mean                         Midtown (CD5)  Summer 2009
#
#       Start_Date  Data Value
# 1118  2023-06-01   43.400816
# 313   2023-06-01   43.332874
# 291   2023-06-01   43.332874
# 345   2023-06-01   41.293185
# 769   2023-06-01   40.417640
# ...          ...         ...
# 913   2009-06-01   18.640000
# 1609  2009-06-01   18.190000
# 873   2009-06-01   17.760000
# 1550  2009-06-01   16.130000
# 1930  2009-06-01   14.380000
#
# [2115 rows x 6 columns]

# %% [markdown]
# ## Shows the 10 highest places with Ozone pollution

# %%
#Shows the 10 highest places with Ozone pollution
# top_ozone.plot(x="Geo Place Name", y="Data Value", kind="bar")
# # df[df["Data Value"] > 40.00 ].plot(x="Geo Place Name", y="Data Value", kind="bar")
df.sort_values("Data Value", ascending=False).iloc[0:10].plot(x="Geo Place Name", y="Data Value", kind="bar")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ## Data Changes Over Time in a Pivot Table

# %%
#Based off of a ChatGPT formatted example:
#Cleanly outputs changes over time
df.groupby(["Geo Place Name", "Time Period"])["Data Value"].max().reset_index().pivot(
    index="Geo Place Name",
    columns="Time Period",
    values="Data Value"
)
# Out:
# Time Period                           Summer 2009  Summer 2010  Summer 2011  \
# Geo Place Name
# Bay Ridge and Dyker Heights (CD10)          25.56        33.44        32.51
# Bayside - Little Neck                       26.29        33.51        33.03
# Bayside Little Neck-Fresh Meadows           25.94        33.40        32.99
# Bayside and Little Neck (CD11)              26.28        33.57        33.12
# Bedford Stuyvesant (CD3)                    23.92        31.75        30.80
# ...                                           ...          ...          ...
# West Queens                                 25.70        33.17        33.00
# Williamsbridge and Baychester (CD12)        26.58        33.81        33.23
# Williamsburg - Bushwick                     24.76        32.38        31.54
# Willowbrook                                 26.04        34.45        33.13
# Woodside and Sunnyside (CD2)                26.36        33.29        32.84
#
# Time Period                           Summer 2012  Summer 2013  Summer 2014  \
# Geo Place Name
# Bay Ridge and Dyker Heights (CD10)          32.99        30.29        30.66
# Bayside - Little Neck                       33.84        30.76        32.26
# Bayside Little Neck-Fresh Meadows           33.66        30.72        32.08
# Bayside and Little Neck (CD11)              33.89        30.83        32.27
# Bedford Stuyvesant (CD3)                    31.57        29.07        29.89
# ...                                           ...          ...          ...
# West Queens                                 33.58        30.68        30.87
# Williamsbridge and Baychester (CD12)        35.02        31.61        31.44
# Williamsburg - Bushwick                     32.28        29.70        30.41
# Willowbrook                                 32.76        30.48        31.13
# Woodside and Sunnyside (CD2)                33.81        30.71        30.95
#
# Time Period                           Summer 2015  Summer 2016  Summer 2017  \
# Geo Place Name
# Bay Ridge and Dyker Heights (CD10)          31.77        33.51        29.20
# Bayside - Little Neck                       31.27        32.99        30.27
# Bayside Little Neck-Fresh Meadows           31.37        33.05        30.18
# Bayside and Little Neck (CD11)              31.36        33.06        30.32
# Bedford Stuyvesant (CD3)                    30.64        32.55        28.87
# ...                                           ...          ...          ...
# West Queens                                 31.57        33.12        29.44
# Williamsbridge and Baychester (CD12)        29.75        33.19        28.93
# Williamsburg - Bushwick                     31.10        32.99        29.33
# Willowbrook                                 31.66        34.68        27.95
# Woodside and Sunnyside (CD2)                31.65        33.37        29.49
#
# Time Period                           Summer 2018  Summer 2019  Summer 2020  \
# Geo Place Name
# Bay Ridge and Dyker Heights (CD10)          30.10        29.74        29.22
# Bayside - Little Neck                       30.98        31.68        30.45
# Bayside Little Neck-Fresh Meadows           31.00        31.73        30.47
# Bayside and Little Neck (CD11)              31.09        31.78        30.66
# Bedford Stuyvesant (CD3)                    29.68        29.57        29.28
# ...                                           ...          ...          ...
# West Queens                                 30.33        29.95        30.94
# Williamsbridge and Baychester (CD12)        31.14        30.16        30.49
# Williamsburg - Bushwick                     29.64        29.34        29.38
# Willowbrook                                 29.36        28.80        27.74
# Woodside and Sunnyside (CD2)                29.70        28.58        30.55
#
# Time Period                           Summer 2021  Summer 2022  Summer 2023
# Geo Place Name
# Bay Ridge and Dyker Heights (CD10)      29.654262    34.846756    35.373717
# Bayside - Little Neck                   30.137755    33.400204    36.889532
# Bayside Little Neck-Fresh Meadows       30.300192    33.720430    36.895921
# Bayside and Little Neck (CD11)          30.336616    33.689617    37.097506
# Bedford Stuyvesant (CD3)                29.606971    33.158248    35.693511
# ...                                           ...          ...          ...
# West Queens                             29.188829    33.562540    34.365989
# Williamsbridge and Baychester (CD12)    30.305932    31.772184    32.923497
# Williamsburg - Bushwick                 29.279334    33.172978    35.499418
# Willowbrook                             29.086208    34.754445    34.652718
# Woodside and Sunnyside (CD2)            28.026083    32.765812    33.535430
#
# [114 rows x 15 columns]

# %% [markdown]
# ## Changes in Ozone Levels in West Queens

# %%
#Watch the Ozone levels change for specific place over time
df[df["Geo Place Name"] == "West Queens"].sort_values("Time Period").plot(x="Time Period", y="Data Value", kind="line")
plt.xticks(rotation=45)

plt.show()


#.plot(x="Time Period", y="Data Value", kind="line")

# # df[df["Data Value"] > 40.00 ].plot(x="Geo Place Name", y="Data Value", kind="bar")
